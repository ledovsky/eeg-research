# %% [markdown]
# # Исследование связаности на кластерах
#
# Первый вариант:
#
#     (F3, F7, T3, C3);     (F4, F8, T4, C4);   (T5, P3, O1);  (T6, P4, O2);  (Fz, Cz, Pz)
#
# Второй вариант:
#
#     (F3, Fz, F4) (F7, T3), (F8, T4), (C3, Cz, C4) (P3, Pz, P4), (T5, O1), (T6, O2)
#
# Третий вариант:
#
#     (F3, F7, T3), (F4, F8, T4), (C3, Cz, C4, Pz), (T5, O1, Р3), (T6, O2, P4)

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../eeg-research/')

from os.path import join

# import pipeline.features
# import pipeline.models
from pipeline.explore import feat_performance

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
path_df = pd.read_csv('../../preproc_data/autists/path_file.csv')
path_df = path_df[path_df['target'] != 'organic']
path_df = path_df[path_df['seconds'] >= 30]
path_df = path_df[~path_df['fn'].isin(['fedya_10_og.csv', 'hartonov-3_asd.csv', 
                                       'voroncova_kristina_5_fon.csv'])]
path_df['age'] = path_df['age'].fillna(0)

# %%
intervals = [
    ('All', 0, 100),
    ('2-4', 2, 4),
    ('5-6', 5, 6),
    ('7+', 7, 100),
    ('7-8', 7, 8),
    ('6-8', 6, 8),
    ('9+', 9, 100), 
]

rows = []
to_select = {}
for name, val_from, val_to in intervals:
    cur_df = path_df[(path_df['age'] >= val_from) & (path_df['age'] <= val_to)]
    to_select[name] = cur_df['fn']
    rows.append({
        'Age': name,
        'N': len(cur_df),
        'N autism': len(cur_df[cur_df['target'] == 'asd']),
        'N hc': len(cur_df[cur_df['target'] == 'typical']),
    })
    
age_summary_df = pd.DataFrame(rows)
age_summary_df
# Out:
#    Age    N  N autism  N hc
# 0  All  203       119    84
# 1  2-4   51        35    16
# 2  5-6   57        26    31
# 3   7+   90        53    37
# 4  7-8   45        31    14
# 5  6-8   69        39    30
# 6   9+   45        22    23

# %%
def get_binary_target(df):
    df = df[df['target'] != 'organic'].copy()
    df['target'] = df['target'].replace('asd', 1).replace('typical', 0).astype(int)
    return df

# %%
def feat_performance_by_age(df, fns_to_select):
    df = df[df['fn'].isin(fns_to_select)]
    features = [col for col in df.columns if col not in ['target', 'fn']]
    return feat_performance(df, features)

# %%
def get_merged_feat_scores(df, df_1, df_2, fns_to_select):

    df = df[df['fn'].isin(fns_to_select)]
    df_1 = df_1[df_1['fn'].isin(fns_to_select)]
    df_2 = df_2[df_2['fn'].isin(fns_to_select)]


    feat_scores_full = feat_performance(df)
    feat_scores_part1 = feat_performance(df_1)
    feat_scores_part2 = feat_performance(df_2)

    feat_scores_merged = (feat_scores_full
        .merge(feat_scores_part1[['feature', 'roc_auc']], on='feature', suffixes=('_full', '_part1'))
        .merge(feat_scores_part2[['feature', 'roc_auc']].rename(columns={'roc_auc': 'roc_auc_part2'}), on='feature'))
    
    feat_scores_merged.sort_values('roc_auc_full', ascending=False, inplace=True)
    
    feat_scores_merged['diff'] = feat_scores_merged.apply(
    lambda row: (
        max(row['roc_auc_full'], row['roc_auc_part1'], row['roc_auc_part2']) - 
        min(row['roc_auc_full'], row['roc_auc_part1'], row['roc_auc_part2'])), 
    axis=1)
    
    return feat_scores_merged

# %% [markdown]
# ## Кластеризация - версия 1

# %%
path = '../own_data/200708_aut_clust_v1/'

df = pd.read_csv(join(path, 'full/set_2.csv'))
df_1 = pd.read_csv(join(path, 'part_1/set_2.csv'))
df_2 = pd.read_csv(join(path, 'part_2/set_2.csv'))

df = get_binary_target(df)
df_1 = get_binary_target(df_1)
df_2 = get_binary_target(df_2)

# %%
get_merged_feat_scores(df, df_1, df_2, to_select['2-4']).head(20)
# Out:
#                       feature  roc_auc_full  mean_difference  roc_auc_part1  \
# 0   coh_theta_clust_3_clust_4      0.755357        -0.094693       0.683929
# 1    coh_beta_clust_0_clust_4      0.701786         0.104450       0.687500
# 2   coh_alpha_clust_3_clust_4      0.694643        -0.079988       0.698214
# 3   coh_alpha_clust_2_clust_3      0.692857        -0.061507       0.691071
# 4   env_theta_clust_2_clust_3      0.683929        -0.090910       0.687500
# 5   env_alpha_clust_3_clust_4      0.683929        -0.123784       0.655357
# 6   env_alpha_clust_1_clust_2      0.682143        -0.117284       0.641071
# 7    env_beta_clust_3_clust_4      0.682143        -0.086390       0.655357
# 8    coh_beta_clust_3_clust_4      0.676786        -0.060882       0.703571
# 9   coh_alpha_clust_1_clust_2      0.676786        -0.054273       0.669643
# 10  env_alpha_clust_1_clust_3      0.669643        -0.090072       0.635714
# 11  coh_theta_clust_2_clust_3      0.669643        -0.046041       0.610714
# 12  env_alpha_clust_2_clust_3      0.669643        -0.116499       0.635714
# 13   env_beta_clust_1_clust_3      0.662500        -0.071514       0.605357
# 14  coh_alpha_clust_1_clust_3      0.657143        -0.064133       0.641071
# 15  coh_alpha_clust_0_clust_4      0.657143         0.054316       0.623214
# 16   env_beta_clust_2_clust_3      0.655357        -0.072825       0.658929
# 17   env_beta_clust_0_clust_4      0.653571         0.135341       0.669643
# 18   coh_beta_clust_2_clust_3      0.653571        -0.057704       0.678571
# 19   env_beta_clust_1_clust_4      0.644643        -0.036980       0.687500
#
#     roc_auc_part2      diff
# 0        0.728571  0.071429
# 1        0.682143  0.019643
# 2        0.689286  0.008929
# 3        0.658929  0.033929
# 4        0.650000  0.037500
# 5        0.717857  0.062500
# 6        0.725000  0.083929
# 7        0.714286  0.058929
# 8        0.685714  0.026786
# 9        0.691071  0.021429
# 10       0.710714  0.075000
# 11       0.669643  0.058929
# 12       0.708929  0.073214
# 13       0.716071  0.110714
# 14       0.721429  0.080357
# 15       0.621429  0.035714
# 16       0.666071  0.010714
# 17       0.651786  0.017857
# 18       0.687500  0.033929
# 19       0.646429  0.042857

# %%
get_merged_feat_scores(df, df_1, df_2, to_select['5-6']).head(20)
# Out:
#                       feature  roc_auc_full  mean_difference  roc_auc_part1  \
# 0   env_alpha_clust_0_clust_1      0.748139        -0.191638       0.760546
# 1   coh_theta_clust_0_clust_1      0.724566        -0.101126       0.734491
# 2   env_theta_clust_2_clust_3      0.700993        -0.105571       0.666253
# 3   coh_alpha_clust_0_clust_1      0.687345        -0.082841       0.703474
# 4   env_theta_clust_0_clust_1      0.686104        -0.131087       0.682382
# 5   coh_theta_clust_2_clust_3      0.684864        -0.044481       0.650124
# 6   env_alpha_clust_2_clust_3      0.677419        -0.101436       0.733251
# 7   env_theta_clust_1_clust_2      0.674938        -0.121589       0.698511
# 8   env_alpha_clust_1_clust_2      0.667494        -0.123707       0.686104
# 9   coh_alpha_clust_1_clust_2      0.660050        -0.055219       0.689826
# 10  coh_alpha_clust_2_clust_3      0.655087        -0.037727       0.717122
# 11   env_beta_clust_0_clust_4      0.651365        -0.168822       0.602978
# 12   coh_beta_clust_2_clust_4      0.646402        -0.085102       0.682382
# 13   env_beta_clust_2_clust_4      0.643921        -0.112459       0.667494
# 14  env_theta_clust_1_clust_3      0.638958        -0.109310       0.583127
# 15  env_alpha_clust_0_clust_3      0.631514        -0.084635       0.627792
# 16  env_alpha_clust_1_clust_4      0.624069        -0.084081       0.624069
# 17   coh_beta_clust_0_clust_4      0.622829        -0.125903       0.586849
# 18  env_theta_clust_2_clust_4      0.617866        -0.104465       0.656328
# 19  env_alpha_clust_0_clust_4      0.606700        -0.080893       0.574442
#
#     roc_auc_part2      diff
# 0        0.693548  0.066998
# 1        0.779156  0.054591
# 2        0.678660  0.034739
# 3        0.686104  0.017370
# 4        0.678660  0.007444
# 5        0.755583  0.105459
# 6        0.614144  0.119107
# 7        0.651365  0.047146
# 8        0.606700  0.079404
# 9        0.662531  0.029777
# 10       0.671216  0.062035
# 11       0.579404  0.071960
# 12       0.569479  0.112903
# 13       0.586849  0.080645
# 14       0.595533  0.055831
# 15       0.617866  0.013648
# 16       0.581886  0.042184
# 17       0.583127  0.039702
# 18       0.503722  0.152605
# 19       0.562035  0.044665

# %%
get_merged_feat_scores(df, df_1, df_2, to_select['7-8']).head(20)
# Out:
#                       feature  roc_auc_full  mean_difference  roc_auc_part1  \
# 0    coh_beta_clust_2_clust_4      0.783410        -0.103023       0.725806
# 1   env_alpha_clust_2_clust_3      0.748848        -0.137377       0.675115
# 2    env_beta_clust_2_clust_4      0.730415        -0.151894       0.739631
# 3   coh_theta_clust_0_clust_1      0.718894        -0.087069       0.682028
# 4    env_beta_clust_0_clust_4      0.714286        -0.186815       0.682028
# 5    coh_beta_clust_0_clust_4      0.700461        -0.123719       0.691244
# 6    env_beta_clust_0_clust_2      0.695853        -0.142052       0.675115
# 7    env_beta_clust_1_clust_2      0.688940        -0.056433       0.633641
# 8    env_beta_clust_2_clust_3      0.686636        -0.104402       0.670507
# 9   env_theta_clust_3_clust_4      0.679724         0.117353       0.705069
# 10   env_beta_clust_0_clust_1      0.677419        -0.064252       0.691244
# 11  env_alpha_clust_0_clust_1      0.670507        -0.115705       0.610599
# 12  coh_alpha_clust_2_clust_3      0.665899        -0.049912       0.564516
# 13   coh_beta_clust_2_clust_3      0.661290        -0.046230       0.617512
# 14  env_theta_clust_0_clust_1      0.656682        -0.104594       0.626728
# 15   env_beta_clust_0_clust_3      0.640553        -0.058982       0.624424
# 16  coh_alpha_clust_1_clust_4      0.635945         0.039663       0.686636
# 17  coh_alpha_clust_2_clust_4      0.633641        -0.053141       0.619816
# 18  coh_theta_clust_1_clust_3      0.631336         0.034712       0.599078
# 19   coh_beta_clust_1_clust_4      0.631336         0.021334       0.677419
#
#     roc_auc_part2      diff
# 0        0.776498  0.057604
# 1        0.746544  0.073733
# 2        0.698157  0.041475
# 3        0.716590  0.036866
# 4        0.760369  0.078341
# 5        0.709677  0.018433
# 6        0.677419  0.020737
# 7        0.700461  0.066820
# 8        0.684332  0.016129
# 9        0.640553  0.064516
# 10       0.622120  0.069124
# 11       0.663594  0.059908
# 12       0.686636  0.122120
# 13       0.640553  0.043779
# 14       0.695853  0.069124
# 15       0.654378  0.029954
# 16       0.557604  0.129032
# 17       0.668203  0.048387
# 18       0.684332  0.085253
# 19       0.626728  0.050691

# %% [markdown]
# ## Кластеризация - версия 2

# %%
path = '../own_data/200708_aut_clust_v2/'

df = pd.read_csv(join(path, 'full/set_2.csv'))
df_1 = pd.read_csv(join(path, 'part_1/set_2.csv'))
df_2 = pd.read_csv(join(path, 'part_2/set_2.csv'))

df = get_binary_target(df)
df_1 = get_binary_target(df_1)
df_2 = get_binary_target(df_2)

# %%
get_merged_feat_scores(df, df_1, df_2, to_select['2-4']).head(20)
# Out:
#                       feature  roc_auc_full  mean_difference  roc_auc_part1  \
# 0    coh_beta_clust_0_clust_1      0.778571         0.150415       0.773214
# 1    env_beta_clust_3_clust_5      0.753571        -0.160306       0.771429
# 2    env_beta_clust_0_clust_1      0.742857         0.211281       0.782143
# 3    env_beta_clust_0_clust_3      0.735714         0.202139       0.769643
# 4    coh_beta_clust_1_clust_2      0.728571         0.111258       0.721429
# 5    env_beta_clust_4_clust_5      0.717857        -0.124624       0.741071
# 6    env_beta_clust_1_clust_2      0.716071         0.185849       0.755357
# 7   coh_alpha_clust_0_clust_1      0.716071         0.073264       0.675000
# 8   env_alpha_clust_3_clust_5      0.714286        -0.158053       0.735714
# 9   coh_alpha_clust_4_clust_5      0.710714        -0.080435       0.683929
# 10   env_beta_clust_2_clust_5      0.708929        -0.091116       0.669643
# 11   coh_beta_clust_2_clust_5      0.703571        -0.058122       0.696429
# 12   coh_beta_clust_4_clust_5      0.703571        -0.079512       0.739286
# 13  coh_alpha_clust_3_clust_5      0.696429        -0.084823       0.692857
# 14  env_alpha_clust_4_clust_5      0.694643        -0.146469       0.680357
# 15   coh_beta_clust_3_clust_5      0.692857        -0.098735       0.705357
# 16   coh_beta_clust_0_clust_3      0.691071         0.114706       0.716071
# 17   coh_beta_clust_0_clust_2      0.683929         0.084704       0.655357
# 18   env_beta_clust_1_clust_3      0.671429         0.147847       0.683929
# 19  coh_theta_clust_2_clust_5      0.666071        -0.064850       0.550000
#
#     roc_auc_part2      diff
# 0        0.755357  0.023214
# 1        0.771429  0.017857
# 2        0.710714  0.071429
# 3        0.694643  0.075000
# 4        0.703571  0.025000
# 5        0.721429  0.023214
# 6        0.667857  0.087500
# 7        0.685714  0.041071
# 8        0.725000  0.021429
# 9        0.682143  0.028571
# 10       0.730357  0.060714
# 11       0.733929  0.037500
# 12       0.733929  0.035714
# 13       0.705357  0.012500
# 14       0.701786  0.021429
# 15       0.708929  0.016071
# 16       0.664286  0.051786
# 17       0.658929  0.028571
# 18       0.607143  0.076786
# 19       0.683929  0.133929

# %%
get_merged_feat_scores(df, df_1, df_2, to_select['5-6']).head(20)
# Out:
#                       feature  roc_auc_full  mean_difference  roc_auc_part1  \
# 0   env_alpha_clust_0_clust_2      0.705955        -0.146598       0.625310
# 1   env_theta_clust_1_clust_5      0.697270        -0.126607       0.671216
# 2   env_theta_clust_4_clust_5      0.691067        -0.116574       0.696030
# 3   env_alpha_clust_4_clust_5      0.686104        -0.098524       0.725806
# 4   coh_theta_clust_1_clust_5      0.684864        -0.065741       0.717122
# 5   coh_alpha_clust_4_clust_5      0.674938        -0.047525       0.739454
# 6    coh_beta_clust_0_clust_2      0.669975        -0.098607       0.617866
# 7   coh_alpha_clust_0_clust_1      0.667494        -0.082271       0.663772
# 8    env_beta_clust_0_clust_2      0.666253        -0.123583       0.600496
# 9   coh_alpha_clust_0_clust_2      0.666253        -0.081002       0.645161
# 10  coh_theta_clust_4_clust_5      0.663772        -0.043329       0.666253
# 11   env_beta_clust_0_clust_1      0.662531        -0.139774       0.621588
# 12   coh_beta_clust_0_clust_1      0.653846        -0.111435       0.650124
# 13  env_alpha_clust_1_clust_5      0.650124        -0.103180       0.691067
# 14  env_alpha_clust_0_clust_1      0.642680        -0.098365       0.604218
# 15  coh_theta_clust_0_clust_2      0.638958        -0.067722       0.610422
# 16  env_theta_clust_0_clust_1      0.635236        -0.091492       0.596774
# 17  coh_alpha_clust_1_clust_5      0.625310        -0.052013       0.682382
# 18  env_alpha_clust_1_clust_4      0.624069        -0.089086       0.677419
# 19  env_theta_clust_0_clust_2      0.619107        -0.083106       0.552109
#
#     roc_auc_part2      diff
# 0        0.666253  0.080645
# 1        0.645161  0.052109
# 2        0.699752  0.008685
# 3        0.638958  0.086849
# 4        0.688586  0.032258
# 5        0.694789  0.064516
# 6        0.647643  0.052109
# 7        0.627792  0.039702
# 8        0.633995  0.065757
# 9        0.661290  0.021092
# 10       0.719603  0.055831
# 11       0.615385  0.047146
# 12       0.635236  0.018610
# 13       0.627792  0.063275
# 14       0.614144  0.038462
# 15       0.601737  0.037221
# 16       0.545906  0.089330
# 17       0.641439  0.057072
# 18       0.560794  0.116625
# 19       0.557072  0.066998

# %%
get_merged_feat_scores(df, df_1, df_2, to_select['7-8']).head(20)
# Out:
#                       feature  roc_auc_full  mean_difference  roc_auc_part1  \
# 0    env_beta_clust_0_clust_1      0.751152        -0.181785       0.755760
# 2    env_beta_clust_4_clust_5      0.737327        -0.126349       0.730415
# 1    env_beta_clust_1_clust_5      0.737327        -0.118424       0.728111
# 3    coh_beta_clust_1_clust_2      0.735023        -0.101678       0.739631
# 4   env_alpha_clust_4_clust_5      0.732719        -0.140178       0.658986
# 5    env_beta_clust_0_clust_2      0.730415        -0.122001       0.679724
# 6    env_beta_clust_0_clust_3      0.728111        -0.123593       0.663594
# 7    env_beta_clust_1_clust_2      0.725806        -0.136186       0.744240
# 8    env_beta_clust_1_clust_3      0.723502        -0.139982       0.677419
# 9    env_beta_clust_3_clust_5      0.711982        -0.127570       0.675115
# 11   coh_beta_clust_0_clust_1      0.709677        -0.110587       0.705069
# 10   env_beta_clust_1_clust_4      0.709677        -0.138026       0.686636
# 12   coh_beta_clust_0_clust_2      0.698157        -0.079058       0.665899
# 13   env_beta_clust_2_clust_4      0.693548        -0.109388       0.617512
# 14  coh_alpha_clust_4_clust_5      0.688940        -0.065657       0.610599
# 15  env_alpha_clust_2_clust_4      0.684332        -0.115368       0.624424
# 16  coh_alpha_clust_0_clust_1      0.684332        -0.081252       0.707373
# 17   coh_beta_clust_1_clust_5      0.682028        -0.049137       0.589862
# 18   env_beta_clust_0_clust_4      0.682028        -0.111517       0.675115
# 19   env_beta_clust_2_clust_3      0.682028        -0.106629       0.585253
#
#     roc_auc_part2      diff
# 0        0.769585  0.018433
# 2        0.732719  0.006912
# 1        0.714286  0.023041
# 3        0.739631  0.004608
# 4        0.746544  0.087558
# 5        0.776498  0.096774
# 6        0.781106  0.117512
# 7        0.668203  0.076037
# 8        0.700461  0.046083
# 9        0.732719  0.057604
# 11       0.711982  0.006912
# 10       0.672811  0.036866
# 12       0.711982  0.046083
# 13       0.693548  0.076037
# 14       0.730415  0.119816
# 15       0.684332  0.059908
# 16       0.682028  0.025346
# 17       0.629032  0.092166
# 18       0.748848  0.073733
# 19       0.739631  0.154378

# %% [markdown]
# ## Кластеризация - версия 3

# %%
path = '../own_data/200708_aut_clust_v3/'

df = pd.read_csv(join(path, 'full/set_2.csv'))
df_1 = pd.read_csv(join(path, 'part_1/set_2.csv'))
df_2 = pd.read_csv(join(path, 'part_2/set_2.csv'))

df = get_binary_target(df)
df_1 = get_binary_target(df_1)
df_2 = get_binary_target(df_2)

# %%
get_merged_feat_scores(df, df_1, df_2, to_select['2-4']).head(20)
# Out:
#                       feature  roc_auc_full  mean_difference  roc_auc_part1  \
# 0   env_theta_clust_2_clust_4      0.710714        -0.154863       0.700000
# 1   coh_theta_clust_2_clust_4      0.710714        -0.088952       0.660714
# 2    coh_beta_clust_0_clust_2      0.701786         0.102038       0.696429
# 3    coh_beta_clust_2_clust_4      0.696429        -0.089767       0.694643
# 4   coh_alpha_clust_3_clust_4      0.692857        -0.061507       0.691071
# 5    env_beta_clust_2_clust_4      0.691071        -0.123526       0.683929
# 6   coh_alpha_clust_1_clust_3      0.689286        -0.059244       0.687500
# 7   env_alpha_clust_1_clust_3      0.689286        -0.121242       0.628571
# 8   env_theta_clust_3_clust_4      0.683929        -0.090910       0.687500
# 9   coh_alpha_clust_2_clust_4      0.682143        -0.087820       0.664286
# 10   env_beta_clust_0_clust_2      0.675000         0.159427       0.689286
# 11  env_alpha_clust_0_clust_1      0.673214        -0.116410       0.653571
# 12  coh_theta_clust_3_clust_4      0.669643        -0.046041       0.610714
# 13  env_alpha_clust_3_clust_4      0.669643        -0.116499       0.635714
# 14  coh_alpha_clust_1_clust_4      0.657143        -0.058756       0.642857
# 15   env_beta_clust_3_clust_4      0.655357        -0.072825       0.658929
# 16   coh_beta_clust_3_clust_4      0.653571        -0.057704       0.678571
# 17  env_alpha_clust_1_clust_4      0.651786        -0.079416       0.598214
# 18  env_alpha_clust_1_clust_2      0.650000        -0.095372       0.639286
# 19  coh_theta_clust_1_clust_3      0.648214        -0.053319       0.617857
#
#     roc_auc_part2      diff
# 0        0.683929  0.026786
# 1        0.739286  0.078571
# 2        0.687500  0.014286
# 3        0.708929  0.014286
# 4        0.658929  0.033929
# 5        0.739286  0.055357
# 6        0.683929  0.005357
# 7        0.741071  0.112500
# 8        0.650000  0.037500
# 9        0.673214  0.017857
# 10       0.633929  0.055357
# 11       0.714286  0.060714
# 12       0.669643  0.058929
# 13       0.708929  0.073214
# 14       0.721429  0.078571
# 15       0.666071  0.010714
# 16       0.687500  0.033929
# 17       0.714286  0.116071
# 18       0.673214  0.033929
# 19       0.692857  0.075000

# %%
get_merged_feat_scores(df, df_1, df_2, to_select['5-6']).head(20)
# Out:
#                       feature  roc_auc_full  mean_difference  roc_auc_part1  \
# 0   env_alpha_clust_0_clust_1      0.760546        -0.193151       0.789082
# 1   coh_theta_clust_0_clust_1      0.744417        -0.115575       0.776675
# 2   env_theta_clust_0_clust_1      0.744417        -0.156618       0.749380
# 3   env_theta_clust_1_clust_3      0.702233        -0.133579       0.736973
# 4   env_theta_clust_3_clust_4      0.700993        -0.105571       0.666253
# 5   env_alpha_clust_1_clust_2      0.698511        -0.135533       0.693548
# 6   env_theta_clust_1_clust_4      0.688586        -0.128376       0.621588
# 7   coh_theta_clust_3_clust_4      0.684864        -0.044481       0.650124
# 8   env_alpha_clust_1_clust_3      0.677419        -0.128445       0.708437
# 9   env_alpha_clust_3_clust_4      0.677419        -0.101436       0.733251
# 10  coh_alpha_clust_1_clust_3      0.663772        -0.056344       0.703474
# 11  coh_alpha_clust_0_clust_1      0.663772        -0.079036       0.700993
# 12  coh_alpha_clust_3_clust_4      0.655087        -0.037727       0.717122
# 13  coh_alpha_clust_1_clust_2      0.652605        -0.054230       0.648883
# 14  coh_theta_clust_0_clust_4      0.647643        -0.049859       0.662531
# 15  env_alpha_clust_0_clust_4      0.642680        -0.085016       0.637717
# 16  env_alpha_clust_1_clust_4      0.626551        -0.095230       0.658809
# 17  coh_alpha_clust_1_clust_4      0.625310        -0.038911       0.662531
# 18  coh_theta_clust_1_clust_3      0.620347        -0.049138       0.691067
# 19  coh_theta_clust_2_clust_3      0.619107        -0.025398       0.614144
#
#     roc_auc_part2      diff
# 0        0.699752  0.089330
# 1        0.791563  0.047146
# 2        0.708437  0.040943
# 3        0.648883  0.088089
# 4        0.678660  0.034739
# 5        0.624069  0.074442
# 6        0.625310  0.066998
# 7        0.755583  0.105459
# 8        0.617866  0.090571
# 9        0.614144  0.119107
# 10       0.684864  0.039702
# 11       0.697270  0.037221
# 12       0.671216  0.062035
# 13       0.676179  0.027295
# 14       0.668734  0.021092
# 15       0.607940  0.034739
# 16       0.535980  0.122829
# 17       0.563275  0.099256
# 18       0.672457  0.070720
# 19       0.615385  0.004963

# %%
get_merged_feat_scores(df, df_1, df_2, to_select['7-8']).head(20)
# Out:
#                       feature  roc_auc_full  mean_difference  roc_auc_part1  \
# 0   env_alpha_clust_3_clust_4      0.748848        -0.137377       0.675115
# 1    coh_beta_clust_2_clust_3      0.728111        -0.088868       0.677419
# 2   coh_theta_clust_0_clust_1      0.705069        -0.093731       0.700461
# 3    env_beta_clust_2_clust_3      0.702765        -0.134491       0.642857
# 4    coh_beta_clust_0_clust_2      0.700461        -0.101062       0.702765
# 5    env_beta_clust_1_clust_3      0.695853        -0.072671       0.640553
# 6    env_beta_clust_0_clust_3      0.693548        -0.135181       0.670507
# 7   env_alpha_clust_0_clust_1      0.686636        -0.135930       0.654378
# 8    env_beta_clust_3_clust_4      0.686636        -0.104402       0.670507
# 9   env_theta_clust_0_clust_1      0.686636        -0.124902       0.668203
# 10   env_beta_clust_0_clust_1      0.684332        -0.087400       0.698157
# 11   env_beta_clust_0_clust_2      0.679724        -0.134876       0.698157
# 12  coh_alpha_clust_3_clust_4      0.665899        -0.049912       0.564516
# 13   coh_beta_clust_3_clust_4      0.661290        -0.046230       0.617512
# 14   env_beta_clust_0_clust_4      0.652074        -0.061508       0.647465
# 15  coh_alpha_clust_1_clust_2      0.645161         0.045917       0.728111
# 16  env_alpha_clust_2_clust_3      0.642857        -0.101308       0.610599
# 17  coh_alpha_clust_0_clust_1      0.642857        -0.058335       0.571429
# 18  coh_theta_clust_1_clust_4      0.624424         0.038008       0.585253
# 19  env_alpha_clust_1_clust_3      0.624424        -0.078926       0.536866
#
#     roc_auc_part2      diff
# 0        0.746544  0.073733
# 1        0.744240  0.066820
# 2        0.725806  0.025346
# 3        0.721198  0.078341
# 4        0.716590  0.016129
# 5        0.705069  0.064516
# 6        0.688940  0.023041
# 7        0.702765  0.048387
# 8        0.684332  0.016129
# 9        0.716590  0.048387
# 10       0.612903  0.085253
# 11       0.732719  0.052995
# 12       0.686636  0.122120
# 13       0.640553  0.043779
# 14       0.649770  0.004608
# 15       0.520737  0.207373
# 16       0.615207  0.032258
# 17       0.691244  0.119816
# 18       0.677419  0.092166
# 19       0.619816  0.087558
